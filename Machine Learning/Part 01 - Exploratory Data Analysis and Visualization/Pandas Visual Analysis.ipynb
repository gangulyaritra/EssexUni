# %% [markdown]
# ![54164pva.jpg](data:image/jpeg;base64,...)
#
# [https://pypi.org/project/pandas-visual-analysis/](https://pypi.org/project/pandas-visual-analysis/)
#
# [https://github.com/meffmadd/pandas-visual-analysis](https://github.com/meffmadd/pandas-visual-analysis)

# %%
# !pip install pandas-visual-analysis

# %%
from pandas_visual_analysis import VisualAnalysis
import pandas as pd

data = pd.read_csv("bank-additional-full.csv", delimiter = ";")

# %%
VisualAnalysis(data)
