# %% [markdown]
# # **Lazy Predict**
#
# Lazy Predict help build a lot of basic models without much code and helps understand which models works better without any parameter tuning.
#
# [https://pypi.org/project/lazypredict/](https://https://pypi.org/project/lazypredict/)
#
# [https://lazypredict.readthedocs.io/en/latest/](https://lazypredict.readthedocs.io/en/latest/)

# %%
# !pip install lazypredict

# %%
# Import Library.
import pandas as pd
import numpy as np
import lazypredict

# %% [markdown]
# # **Lazy Classifier**

# %%
# Load Dataset.
data = pd.read_csv('CE802_Ass_2019_Data.csv')
data.head()
# Out:
#    F1  F2   F3    F4    F5    F6  ...   F16   F17   F18   F19  F20  Class
# 0   0   0   16  2.02  0.52 -2.35  ... -3.49 -1.68  0.02 15.30  nan   True
# 1   0   0   86 -0.90  2.75  0.14  ...  0.34  0.36  0.61 10.10  nan   True
# 2   1   1  165  0.73  1.05  0.10  ... -0.62  1.67  2.60 11.00 1.55  False
# 3   1   1  191 -1.50  0.79  0.33  ...  0.63  0.08  0.19  6.30 0.95  False
# 4   1   1   13  0.25 -1.19 -0.90  ... -2.41 -0.53 -0.77 10.50  nan   True
#
# [5 rows x 21 columns]

# %%
# Split the dataset into features and the target variable.
X = data.iloc[:, :-2]
y = data.iloc[:, -1]

# Feature Scaling.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# Split the dataset into the Training set and Test set.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose = 0, ignore_warnings = True, custom_metric = None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 19.82it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# NuSVC                              0.68  ...        0.03
# KNeighborsClassifier               0.63  ...        0.02
# QuadraticDiscriminantAnalysis      0.62  ...        0.01
# XGBClassifier                      0.62  ...        0.11
# LGBMClassifier                     0.61  ...        0.10
# LabelPropagation                   0.59  ...        0.03
# LabelSpreading                     0.59  ...        0.04
# RandomForestClassifier             0.60  ...        0.23
# DummyClassifier                    0.59  ...        0.01
# SVC                                0.58  ...        0.03
# ExtraTreesClassifier               0.57  ...        0.17
# LogisticRegression                 0.55  ...        0.03
# RidgeClassifierCV                  0.55  ...        0.02
# RidgeClassifier                    0.55  ...        0.02
# LinearSVC                          0.55  ...        0.06
# LinearDiscriminantAnalysis         0.54  ...        0.03
# AdaBoostClassifier                 0.54  ...        0.14
# SGDClassifier                      0.54  ...        0.02
# ExtraTreeClassifier                0.52  ...        0.01
# GaussianNB                         0.52  ...        0.02
# CalibratedClassifierCV             0.53  ...        0.16
# PassiveAggressiveClassifier        0.50  ...        0.02
# BaggingClassifier                  0.50  ...        0.06
# NearestCentroid                    0.46  ...        0.02
# Perceptron                         0.45  ...        0.02
# BernoulliNB                        0.46  ...        0.02
# DecisionTreeClassifier             0.45  ...        0.02
#
# [27 rows x 5 columns]

# %% [markdown]
# # **Lazy Regressor**

# %%
# Load Dataset.
data = pd.read_csv("dataset_Facebook.csv", delimiter = ";")
data = data.dropna()  # Drop Missing Values.
data.head()
# Out:
#    Page total likes    Type  Category  ...    like  share  Total Interactions
# 0            139441   Photo         2  ...   79.00  17.00                 100
# 1            139441  Status         2  ...  130.00  29.00                 164
# 2            139441   Photo         3  ...   66.00  14.00                  80
# 3            139441   Photo         2  ... 1572.00 147.00                1777
# 4            139441   Photo         2  ...  325.00  49.00                 393
#
# [5 rows x 19 columns]

# %%
# Encoding Categorical Values.
from sklearn.preprocessing import LabelEncoder
data[["Type"]] = data[["Type"]].apply(LabelEncoder().fit_transform)

# Split the dataset into features and the target variable.
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# Feature Scaling.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# Split the dataset into the Training set and Test set.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from lazypredict.Supervised import LazyRegressor

reg = LazyRegressor(verbose = 0, ignore_warnings = False, custom_metric = None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

models
# Out:
#  26%|██▌       | 11/42 [00:00<00:02, 15.47it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
# 100%|██████████| 42/42 [00:03<00:00, 11.79it/s]
#                                Adjusted R-Squared  ...  Time Taken
# Model                                              ...
# LassoLarsCV                                  1.00  ...        0.02
# LassoLarsIC                                  1.00  ...        0.01
# OrthogonalMatchingPursuitCV                  1.00  ...        0.02
# TransformedTargetRegressor                   1.00  ...        0.02
# LarsCV                                       1.00  ...        0.05
# Lars                                         1.00  ...        0.05
# LinearRegression                             1.00  ...        0.01
# RANSACRegressor                              1.00  ...        0.02
# BayesianRidge                                1.00  ...        0.01
# HuberRegressor                               1.00  ...        0.07
# LassoCV                                      1.00  ...        0.08
# RidgeCV                                      1.00  ...        0.01
# PassiveAggressiveRegressor                   1.00  ...        0.02
# Lasso                                        1.00  ...        0.03
# Ridge                                        1.00  ...        0.01
# SGDRegressor                                 1.00  ...        0.02
# ElasticNetCV                                 0.99  ...        0.07
# OrthogonalMatchingPursuit                    0.99  ...        0.02
# LassoLars                                    0.99  ...        0.01
# ElasticNet                                   0.97  ...        0.01
# LinearSVR                                    0.92  ...        0.01
# GeneralizedLinearRegressor                   0.92  ...        0.04
# TweedieRegressor                             0.92  ...        0.01
# KernelRidge                                  0.87  ...        0.06
# XGBRegressor                                 0.47  ...        0.10
# ExtraTreeRegressor                           0.47  ...        0.01
# ExtraTreesRegressor                          0.43  ...        0.26
# GradientBoostingRegressor                    0.43  ...        0.21
# AdaBoostRegressor                            0.43  ...        0.12
# BaggingRegressor                             0.40  ...        0.06
# MLPRegressor                                 0.40  ...        1.05
# RandomForestRegressor                        0.39  ...        0.40
# DecisionTreeRegressor                        0.38  ...        0.02
# KNeighborsRegressor                          0.38  ...        0.02
# HistGradientBoostingRegressor                0.31  ...        0.31
# LGBMRegressor                                0.31  ...        0.08
# DummyRegressor                              -0.23  ...        0.01
# NuSVR                                       -0.24  ...        0.04
# SVR                                         -0.25  ...        0.03
# GaussianProcessRegressor                    -0.34  ...        0.04
# PoissonRegressor                      -5564549.21  ...        0.04
#
# [41 rows x 4 columns]
